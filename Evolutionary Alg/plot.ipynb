# %%
import matplotlib.pyplot as plt

# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [1406.8965517241377, 1450.8620689655172, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319, 1510.7547169811319]

plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test A (Small Population)")
plt.grid(True)
plt.show()

# %%
# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [30348.14814814815, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 30440.595238095237, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31077.338709677424, 31148.29365079365, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617, 31563.225806451617]
plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test B (Small Population, More Items)")
plt.grid(True)
plt.show()

# %%
# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [5166.666666666666, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5336.448598130841, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5446.601941747573, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5465.346534653465, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077, 5576.923076923077]
plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test C (Moderate Population)")
plt.grid(True)
plt.show()

# %%
# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [5151.401869158878, 5755.7009345794395, 5890.973451327433, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 
6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 
6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965, 6026.2962962962965]
plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test D (Large Population)")
plt.grid(True)
plt.show()

# %%
# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [4975.714285714285, 5596.363636363636, 5730.810810810811, 5730.810810810811, 5730.810810810811, 5730.810810810811, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727, 5871.272727272727]
plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test E (Higher Mutation)")
plt.grid(True)
plt.show()

# %%
# Sample fitness history for Test A (replace with your actual numbers)
fitness_history_A = [5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5436.880733944954, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 
5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 
5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835, 5743.68932038835]
plt.figure(figsize=(10, 6))
plt.plot(fitness_history_A, marker='o')
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Over Generations - Test F (Higher Mutation and Lower Crossover Probability)")
plt.grid(True)
plt.show()
